# %%
from plyfile import PlyData, PlyElement
import pyqtgraph as pg
import pyqtgraph.opengl as gl

# %%
plydata = PlyData.read('/Users/eric/Desktop/shuttlecock/test.ply')

# %%
plydata
# Out:
# PlyData((PlyElement('vertex', (PlyProperty('x', 'float'), PlyProperty('y', 'float'), PlyProperty('z', 'float')), count=24386, comments=[]), PlyElement('face', (PlyListProperty('vertex_indices', 'uchar', 'int'), PlyProperty('red', 'uchar'), PlyProperty('green', 'uchar'), PlyProperty('blue', 'uchar'), PlyProperty('alpha', 'uchar')), count=48704, comments=[])), text=False, byte_order='<', comments=[], obj_info=[])

# %%
_facecolor = []

# %%
print (plydata.elements[1])
for data in plydata.elements[1]:
    _facecolor.append((data[1],data[2],data[3],data[4]))
# Out:
# element face 48704
# property list uchar int vertex_indices
# property uchar red
# property uchar green
# property uchar blue
# property uchar alpha

# %%
_facecolor
# Out:
# [(200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  (200, 200, 200, 255),
#  ...]
